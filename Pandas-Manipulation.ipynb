# %%
# four most common types of data manipulation: 
# sorting rows, 
# subsetting columns, 
# subsetting rows, 
# adding new columns

# %%
import pandas as pd

# dataset used is an open data set which comes from kaggle
# source: https://www.kaggle.com/doaaalsenani/usa-cers-dataset/data

filepath = '/Users/tianyiwei/Desktop/wty/'
df_car = pd.read_csv(filepath+'USA_cars_datasets.csv')

# %%
df_car = df_car.iloc[:,1:]
df_car
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df_car.info()  # columns, dtype, na
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 12 columns):
# price           2499 non-null int64
# brand           2499 non-null object
# model           2499 non-null object
# year            2499 non-null int64
# title_status    2499 non-null object
# mileage         2499 non-null float64
# color           2499 non-null object
# vin             2499 non-null object
# lot             2499 non-null int64
# state           2499 non-null object
# country         2499 non-null object
# condition       2499 non-null object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 234.4+ KB

# %%
df_car.describe()  # count/mean/min/max  #stats
# Out:
#               price         year       mileage           lot
# count   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std    12116.094936     3.442656  5.970552e+04  2.038772e+05
# min        0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%    10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %% [markdown]
# ### Sort Values

# %%
# list top5 price
df_car.sort_values(by='price',ascending=False).head()

# sort by multiple columns
df_car.sort_values(by=['price','year'],ascending=[False,False]).head()  # same price with latest year
# Out:
#       price          brand       model  year   title_status  mileage  \
# 502   84900  mercedes-benz    sl-class  2017  clean vehicle  25302.0
# 1340  74000           ford         drw  2019  clean vehicle  10536.0
# 1336  70000           ford         drw  2019  clean vehicle   9643.0
# 277   67000          dodge  challenger  2019  clean vehicle  10944.0
# 1215  65500           ford         srw  2019  clean vehicle   6500.0
#
#          color                  vin        lot     state country  \
# 502     silver    wddjk7ea3hf044968  167607883   florida     usa
# 1340  no_color    1ft8w4dt6ked32656  167780682  illinois     usa
# 1336  no_color    1ft8w3dt3kee48276  167780680  illinois     usa
# 277       blue    2c3cdzl97kh518237  167759490      ohio     usa
# 1215     black    1ft7w2bt0kec44818  167718954   indiana     usa
#
#           condition
# 502     2 days left
# 1340    2 days left
# 1336    2 days left
# 277   21 hours left
# 1215  21 hours left

# %% [markdown]
# ### Subset Columns

# %%
# subset part of the columns
df_car_pbm = df_car[['price','brand','model']]
df_car_pbm.head()
# Out:
#    price      brand    model
# 0   6300     toyota  cruiser
# 1   2899       ford       se
# 2   5350      dodge      mpv
# 3  25000       ford     door
# 4  27700  chevrolet     1500

# %% [markdown]
# ### Subset Rows

# %%
# multiple conditions filter
df_car[(df_car['price']<=22000)&(df_car['brand']=='chevrolet')&(df_car['year']>=2019)].head()

# put true flase in [] to filter: df_car[a series of True/False]
# Out:
#      price      brand   model  year       title_status  mileage  color  \
# 206     25  chevrolet  vehicl  2020  salvage insurance   7232.0  black
# 213  15500  chevrolet    trax  2020      clean vehicle  16545.0  white
# 222  16300  chevrolet    trax  2020      clean vehicle  18221.0  white
# 266  17100  chevrolet  malibu  2019      clean vehicle  15780.0  white
# 278  18900  chevrolet  impala  2019      clean vehicle  27601.0  white
#
#                      vin        lot       state country      condition
# 206    2gnaxkev6l6128374  167756877    kentucky     usa    3 days left
# 213    3gncjlsb1ll142267  167765995     georgia     usa    3 days left
# 222    3gncjlsb4ll149763  167766003     georgia     usa    3 days left
# 266    1g1zd5st5kf112138  167767034  washington     usa    2 days left
# 278    1g11z5s37ku129047  167767312       texas     usa  21 hours left

# %%
# Subsetting rows by categorical variables
my_favorite_brand = ['chevrolet','cadillac','audi']
condition = df_car['brand'].isin(my_favorite_brand)

df_car[df_car['brand'].isin(my_favorite_brand)]  # subset
# Out:
#      price      brand     model  year   title_status   mileage   color  \
# 4    27700  chevrolet      1500  2018  clean vehicle    6654.0     red
# 6     7300  chevrolet        pk  2010  clean vehicle  149050.0   black
# 8    14600  chevrolet    malibu  2018  clean vehicle    9371.0  silver
# 12   31900  chevrolet      1500  2018  clean vehicle   22909.0   black
# 22   15000  chevrolet      door  2015  clean vehicle   61578.0   black
# ..     ...        ...       ...   ...            ...       ...     ...
# 803  28300  chevrolet        ld  2019  clean vehicle   27665.0     red
# 804  27300  chevrolet        ld  2019  clean vehicle   25427.0   black
# 805   3500  chevrolet      door  2013  clean vehicle   78198.0    gray
# 806  28300  chevrolet  colorado  2020  clean vehicle   13886.0  silver
# 807  18300  chevrolet    impala  2019  clean vehicle   34538.0  silver
#
#                      vin        lot       state country      condition
# ...

# %% [markdown]
# ### Adding New Columns

# %%
df_car['price_in_thousand'] = df_car['price']/1000
df_car.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#                    vin        lot       state country      condition  \
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
#
#    price_in_thousand
# 0              6.300
# 1              2.899
# 2              5.350
# 3             25.000
# 4             27.700

# %% [markdown]
# ### Aggregating

# %%
df_car['price'].max()
# Out:
# 84900

# %%
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

df_car['price'].agg(iqr)
# Out:
# 15355.5

# %%
df_car['price'].cumsum()  #cumulative sum-max-aggregating function can be a series of data instead of 1 value
# Out:
# 0           6300
# 1           9199
# 2          14549
# 3          39549
# 4          67249
#           ...
# 2494    46863611
# 2495    46872811
# 2496    46882011
# 2497    46891211
# 2498    46900411
# Name: price, Length: 2499, dtype: int64

# %%
# drop duplicates
df_car.drop_duplicates(subset=['brand','model','year'])
# Out:
#       price      brand    model  year       title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008      clean vehicle  274117.0   black
# 1      2899       ford       se  2011      clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018      clean vehicle   39590.0  silver
# 3     25000       ford     door  2014      clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018      clean vehicle    6654.0     red
# ...     ...        ...      ...   ...                ...       ...     ...
# 2387  14600     nissan    rogue  2016      clean vehicle   31566.0    gray
# 2423   6500     nissan     door  2014      clean vehicle   65620.0   white
# 2438  22700     nissan      nvp  2016      clean vehicle   21282.0   white
# 2440   5475     nissan     door  2018  salvage insurance   33048.0   black
# 2473  30100     nissan    titan  2019      clean vehicle   30599.0   black
#
# ...

# %%
# count categorical variables
df_car['brand'].value_counts(sort=True, normalize=True)
# Out:
# ford               0.494198
# dodge              0.172869
# nissan             0.124850
# chevrolet          0.118848
# gmc                0.016807
# jeep               0.012005
# chrysler           0.007203
# bmw                0.006803
# hyundai            0.006002
# kia                0.005202
# buick              0.005202
# infiniti           0.004802
# honda              0.004802
# mercedes-benz      0.004002
# cadillac           0.004002
# heartland          0.002001
# peterbilt          0.001601
# land               0.001601
# audi               0.001601
# acura              0.001200
# mazda              0.000800
# lexus              0.000800
# lincoln            0.000800
# toyota             0.000400
# harley-davidson    0.000400
# maserati           0.000400
# jaguar             0.000400
# ram                0.000400
# Name: brand, dtype: float64

# %%
# group by aggregation
df_car.groupby(by=['brand'])['price'].mean()  # df_car.groupby(by=['brand','year'])['price'].mean()
# Out:
# brand
# acura               7266.666667
# audi               13981.250000
# bmw                26397.058824
# buick              19715.769231
# cadillac           24941.000000
# chevrolet          18669.952862
# chrysler           13686.111111
# dodge              17781.988426
# ford               21666.888259
# gmc                10657.380952
# harley-davidson    54680.000000
# heartland           2966.000000
# honda               6127.500000
# hyundai             5203.200000
# infiniti           13098.333333
# jaguar              2800.000000
# jeep               10933.833333
# kia                11123.846154
# land               28900.000000
# lexus              33220.000000
# lincoln            18150.000000
# maserati           30300.000000
# mazda               8000.000000
# mercedes-benz      28704.000000
# nissan             12065.820513
# peterbilt            400.000000
# ram                11050.000000
# toyota              6300.000000
# Name: price, dtype: float64

# %%
# group by and multiple statistics
import numpy as np

df_car.groupby(by='brand')['price'].agg([np.min,np.max,np.mean])
# Out:
#                   amin   amax          mean
# brand
# acura             1000  16900   7266.666667
# audi                 0  36400  13981.250000
# bmw                  0  61200  26397.058824
# buick                0  37500  19715.769231
# cadillac             0  47500  24941.000000
# chevrolet            0  63200  18669.952862
# chrysler            25  29100  13686.111111
# dodge                0  67000  17781.988426
# ford                 0  74000  21666.888259
# gmc                  0  48500  10657.380952
# harley-davidson  54680  54680  54680.000000
# heartland            0   6680   2966.000000
# honda                0  17200   6127.500000
# hyundai           3250   9800   5203.200000
# infiniti         10050  18500  13098.333333
# jaguar            2800   2800   2800.000000
# jeep                25  21100  10933.833333
# kia                  0  21500  11123.846154
# land             22500  46900  28900.000000
# lexus            10840  55600  33220.000000
# ...

# %%
# pivot tables(alternative to group by)
df_car.pivot_table(index=['brand'],columns=['year'],values='price',aggfunc=[np.mean],fill_value=0)
# Out:
#                   mean                                                     \
# year              1973 1984 1993  1994 1995 1996 1997      1998 1999 2000
# brand
# acura                0    0    0   0.0    0    0    0  0.000000    0    0
# audi                 0    0    0   0.0    0    0    0  0.000000    0    0
# bmw                  0    0    0   0.0    0    0    0  0.000000    0    0
# buick                0    0    0   0.0    0    0    0  0.000000    0    0
# cadillac             0    0    0   0.0    0    0    0  0.000000    0    0
# chevrolet        29800    0    0   0.0    0    0    0  0.000000    0    0
# chrysler             0    0    0   0.0    0    0    0  0.000000    0  175
# dodge                0    0    0   0.0    0    0    0  0.000000    0    0
# ford                 0   25    0  12.5    0    0    0  8.333333    0    0
# gmc                  0    0    0   0.0    0    0    0  0.000000    0    0
# harley-davidson      0    0    0   0.0    0    0    0  0.000000    0    0
# ...

# %% [markdown]
# ### Slicing and Indexing

# %%
df_car_index = df_car.set_index(['brand','model'])  #  multi-level
# df_car_index.reset_index()
df_car_index
# Out:
#                    price  year   title_status   mileage   color  \
# brand     model
# toyota    cruiser   6300  2008  clean vehicle  274117.0   black
# ford      se        2899  2011  clean vehicle  190552.0  silver
# dodge     mpv       5350  2018  clean vehicle   39590.0  silver
# ford      door     25000  2014  clean vehicle   64146.0    blue
# chevrolet 1500     27700  2018  clean vehicle    6654.0     red
# ...                  ...   ...            ...       ...     ...
# nissan    versa     7800  2019  clean vehicle   23609.0     red
#           versa     9200  2018  clean vehicle   34553.0  silver
#           versa     9200  2018  clean vehicle   31594.0  silver
#           versa     9200  2018  clean vehicle   32557.0   black
#           versa     9200  2018  clean vehicle   31371.0  silver
#
#                                    vin        lot       state country  \
# brand     model
# toyota    cruiser    jtezu11f88k007763  159348797  new jersey     usa
# ...

# %%
df_car_index = df_car_index.sort_index()

# take subsets in both directions at once
df_car_index.loc[('acura','door'):('audi','door'), 'price':'color']
# Out:
#              price  year       title_status   mileage   color
# brand model
# acura door    1000  2008  salvage insurance  118250.0    gray
#       door    3900  2009      clean vehicle  179389.0   black
#       mdx    16900  2014      clean vehicle   63500.0  silver
# audi  5      36400  2015      clean vehicle   47213.0   black
#       door      25  2008  salvage insurance  177422.0   black
#       door       0  2005  salvage insurance  181896.0   black

# %%
# filter rows by a range of values at 1 col
df_car[(df_car['price']>=15000)&(df_car['price']<=25000)]
# Out:
#       price      brand       model  year   title_status   mileage   color  \
# 3     25000       ford        door  2014  clean vehicle   64146.0    blue
# 14    20700       ford        door  2013  clean vehicle  100757.0   black
# 17    16500      buick      encore  2018  clean vehicle   20002.0     red
# 22    15000  chevrolet        door  2015  clean vehicle   61578.0   black
# 24    20800       ford        door  2013  clean vehicle  105510.0  silver
# ...     ...        ...         ...   ...            ...       ...     ...
# 2462  16500     nissan  pathfinder  2018  clean vehicle   36714.0   black
# 2467  16500     nissan  pathfinder  2018  clean vehicle   39454.0  silver
# 2468  16500     nissan  pathfinder  2018  clean vehicle   40203.0    blue
# 2471  18800     nissan  pathfinder  2019  clean vehicle   31123.0   white
# 2478  22800     nissan    frontier  2019  clean vehicle   24320.0   black
#
#                       vin        lot           state country      condition
# ...

# %% [markdown]
# ### Visualizing DataFrames

# %%
import matplotlib.pyplot as plt

brand_num_count = df_car.groupby(by='brand')['model'].count()
brand_num_count.plot(kind = 'bar')
plt.show()

# %%
# scatter plot
df_car.plot(kind = 'scatter',x='mileage',y='price')
plt.show()

# %%
# histogram
df_car[df_car['color']=='red']['price'].hist(alpha=0.5,bins=20)
df_car[df_car['color']=='black']['price'].hist(alpha=0.5,bins=20)
plt.legend(['red','black'])
plt.show()

# %% [markdown]
# ### Missing Values

# %%
df_car_na = df_car
df_car_na.iloc[3,5]=np.nan

df_car_na.isna().any()  # check if any column has missing values
# Out:
# price           False
# brand           False
# model           False
# year            False
# title_status    False
# mileage          True
# color           False
# vin             False
# lot             False
# state           False
# country         False
# condition       False
# dtype: bool

# %%
# df_car_na.dropna()  # drop out the row with na
df_car_na.fillna(1)  # fill na with 1
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle       1.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#                       vin        lot       state country      condition
# ...
